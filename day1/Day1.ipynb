# %%
import pandas as pd

# %%
# Read Data From Google Drive
data = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/electricity consumption2.xlsx")

# %%
data.head()
# Out:
#   Meter_ID Reading_Date       Area Customer_Type  Units_kWh  Tariff_per_kWh  \
# 0  MTR0003   2025-07-29  Mogadishu    Commercial     1955.8           0.212
# 1  MTR0004   2025-02-11     Baidoa    Commercial     1900.5           0.225
# 2  MTR0005   2025-03-01    Kismayo    Commercial     1713.4           0.216
# 3  MTR0014   2026-05-11  Mogadishu    Commercial        0.0           0.228
# 4  MTR0015   2025-06-14     Baidoa    Commercial     2125.0           0.215
#
#   Payment_Status  Total Revenue
# 0           Paid       414.6296
# 1           Paid       427.6125
# 2           Paid       370.0944
# 3        Pending         0.0000
# 4        non_pay       456.8750

# %%
data.tail()
# Out:
#     Meter_ID Reading_Date       Area Customer_Type  Units_kWh  Tariff_per_kWh  \
# 295  MTR0249   2026-03-01    Kismayo  non_customer     3446.1           0.252
# 296  MTR0250   2025-08-09     Garowe  non_customer      699.7           0.223
# 297  MTR0284   2025-04-02   Hargeisa  non_customer      989.4           0.223
# 298  MTR0299   2025-10-30  Mogadishu  non_customer      529.7           0.186
# 299  MTR0300   2025-10-04     Bosaso  non_customer     4843.1           0.253
#
#     Payment_Status  Total Revenue
# 295        Overdue       868.4172
# 296        Pending       156.0331
# 297        pending       220.6362
# 298        Pending        98.5242
# 299           Paid      1225.3043

# %%
data.sample(5)
# Out:
#     Meter_ID Reading_Date       Area Customer_Type  Units_kWh  Tariff_per_kWh  \
# 204  MTR0172   2025-10-17     Bosaso   Residential      212.1           0.189
# 71   MTR0286   2026-07-11     Baidoa    Commercial     1425.9           0.217
# 189  MTR0148   2025-05-22     Baidoa   Residential      356.3           0.188
# 3    MTR0014   2026-05-11  Mogadishu    Commercial        0.0           0.228
# 203  MTR0171   2025-10-16  Mogadishu   Residential      349.4           0.182
#
#     Payment_Status  Total Revenue
# 204           Paid        40.0869
# 71            Paid       309.4203
# 189        Pending        66.9844
# 3          Pending         0.0000
# 203           Paid        63.5908

# %%
data.shape
# Out:
# (300, 8)

# %%
data.columns
# Out:
# Index(['Meter_ID', 'Reading_Date', 'Area', 'Customer_Type', 'Units_kWh',
#        'Tariff_per_kWh', 'Payment_Status', 'Total Revenue'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Meter_ID                  object
# Reading_Date      datetime64[ns]
# Area                      object
# Customer_Type             object
# Units_kWh                float64
# Tariff_per_kWh           float64
# Payment_Status            object
# Total Revenue            float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Meter_ID        300 non-null    object
#  1   Reading_Date    300 non-null    datetime64[ns]
#  2   Area            300 non-null    object
#  3   Customer_Type   300 non-null    object
#  4   Units_kWh       300 non-null    float64
#  5   Tariff_per_kWh  300 non-null    float64
#  6   Payment_Status  300 non-null    object
#  7   Total Revenue   300 non-null    float64
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 18.9+ KB

# %%
data.describe(include="all")
# Out:
#        Meter_ID         Reading_Date       Area Customer_Type     Units_kWh  \
# count       300                  300        300           300    300.000000
# unique      300                  NaN          9             4           NaN
# top     MTR0300                  NaN  Mogadishu   Residential           NaN
# freq          1                  NaN         98           187           NaN
# mean        NaN  2025-10-17 08:04:48        NaN           NaN    974.805667
# min         NaN  2025-01-01 00:00:00        NaN           NaN      0.000000
# 25%         NaN  2025-06-18 18:00:00        NaN           NaN    238.600000
# 50%         NaN  2025-10-21 00:00:00        NaN           NaN    468.600000
# 75%         NaN  2026-02-17 06:00:00        NaN           NaN   1005.325000
# max         NaN  2026-08-01 00:00:00        NaN           NaN  10022.000000
# std         NaN                  NaN        NaN           NaN   1482.763413
#
#         Tariff_per_kWh Payment_Status  Total Revenue
# ...
